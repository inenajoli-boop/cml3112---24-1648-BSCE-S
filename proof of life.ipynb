# %% [markdown]
# <a href="https://colab.research.google.com/github/inenajoli-boop/cml3112---24-1648-BSCE-S/blob/main/proof%20of%20life.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
STUDENT_ID = "24/1648/BSCE-S"
COHORT = "CML3112"

# %%
print("Hello from CML3112")
proof_sum = 2 + 2
print(proof_sum)
# Out:
# Hello from CML3112
# 4

# %%
readings = 12

# %%
readings = readings + 5
print(readings)
# Out:
# 17
